# %% [markdown]
# <a href="https://colab.research.google.com/github/sayalishevale/sayalishevale/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.DataFrame(index=['Ankita','Tejashri','Sayali','Mitali','Vanshika'],
                  data={'Apples':[20, 10, 40, 20, 50],
                        'Oranges':[35, 40, 25, 19, 33]})
df
# Out:
#           Apples  Oranges
# Ankita        20       35
# Tejashri      10       40
# Sayali        40       25
# Mitali        20       19
# Vanshika      50       33

# %%
# Pandas Built-in Data Visualization

# %%
df1 = pd.read_csv('/content/df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/content/df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# Bar Plot

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2['a'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(x='Apples',y='oranges',kind='scatter',title='Scatterplot')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'oranges'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.plot(kind='line',title='Line plot')
# Out:
# <Axes: title={'center': 'Line plot'}>

# %%
df.plot(kind='bar',title='Bar plot')
# Out:
# <Axes: title={'center': 'Bar plot'}>

# %%
# KDE Plot

# %%
df.plot(kind='kde',figsize=(16,4))
# Out:
# <Axes: ylabel='Density'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Apples'}>,
#         <Axes: title={'center': 'Oranges'}>]], dtype=object)

# %%
df.sort_values('Apples').plot(x='Apples',y='Oranges',kind='line')
# Out:
# <Axes: xlabel='Apples'>

# %%
df.plot(x='Apples',y='Oranges',kind='bar')
# Out:
# <Axes: xlabel='Apples'>

# %%
df.plot(x='Apples',kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Area

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.4);

# %%
# Barh

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
# Barplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# Histograms

# %%
df.plot.hist(bins=100, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Line Plots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)
# Out:
# <Axes: >

# %%
# Scatter Plots

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200, c='C', cmap='coolwarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
# BoxPlots

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
# Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
# Kernel Density Estimation plot (KDE)

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>
